# %% [markdown]
# <a href="https://colab.research.google.com/github/pbelouin-mpiwg/combio/blob/master/IMPRS_workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction
#
# The goal of this session is to introduce you to a number of tools allowing you to perform simple text preparation and analysis tasks, which you can apply to your own corpus. In this notebook, we will go through a short example of how to extract information from your texts using NLP techniques.
#
# ### ⚠️ Important
#
# **To start, click the button "Copy to Drive" above this text to create your very own working copy of this notebook! You will need to have a google account.**

# %% [markdown]
# ## Loading our Text
# We need to load the documents we will be analysing into a python "dictionary". First, we need to upload the folder containing our documents to colab. You can find a zip file containing the data [here](https://github.com/pbelouin/imprs_workshop/blob/main/corpus.zip).
#
# After unzipping it, upload it to Colab files.
#
# Once this is done, we need a bit of code to load each document into a variable, and add each variable to our dictionary.

# %%
file_1 = open('/content/2015.txt', 'r')
text_1 = file_1.read()
file_1.close()

file_2 = open('/content/2016.txt', 'r')
text_2 = file_2.read()
file_2.close()


file_3 = open('/content/2017.txt', 'r')
text_3 = file_3.read()
file_3.close()


file_4 = open('/content/2018.txt', 'r')
text_4 = file_4.read()
file_4.close()

file_5 = open('/content/2019.txt', 'r')
text_5 = file_5.read()
file_5.close()

file_6 = open('/content/2020.txt', 'r')
text_6 = file_6.read()
file_6.close()

file_7 = open('/content/2022.txt', 'r')
text_7 = file_7.read()
file_7.close()

file_8 = open('/content/2023.txt', 'r')
text_8 = file_8.read()
file_8.close()

text_8
# Out:
# 'Two-Fold Revolutions: Computational Museology in the Age of Experience\nKenderdine, Sarah . 22\nContesting power in the digital age: the role of civil society in Europe\nFernandez, Claire  23\nWorkshops\nADHO Community Forum: Transparency, Trust, Engagement, Diversity\nLayne-Worthey, Glen; Jakacki, Diane; Brown, Susan; Schöch, Christof . 25\nA Model for Modeling Problems - Game Design as an Exercise in Formal Abstraction\nPielström, Steffen; Wintjes, Jorit  25\nAmplifying unheard voices in Digital Humanities: an OpenMethods edit-a-thon\nTóth-Czifra, Erzsébet; Wuttke, Ulrike; Horváth, Alíz; Nunn, Christopher  26\nAn introduction to Transkribus: how to use Handwritten Text Recognition in research and teaching\nMansutti, Sara . 28\nAudiAnnotate Workshop with Radio Venceremos, Rebel Radio Station and SpokenWeb: Using IIIF with AV to Build Editions and Exhibits.\nClement, Tanya; Bursztajn-Illingworth, Zoe; Wintermeier, Trent; Burrows, Vera . 29\nCreating a DH workflow in the SSH Open Marketplace\nBarbot, Laure; Battaner Moro, Elena; Buddenbohm, Stefan; Concordia, Cesare; Dolinar, Maja; Ďurčo, Matej; Gray, Edward;\nGrisot, Cristina; Illmayer, Klaus; Kirnbauer, Martin; Kleemola, Mari; König, Alexander; Kurzmeier, Michael; McGillivray,\nBarbara; Parente Boavida, Clara; Schuster, Christian; Vipavc Brvar, Irena; Wnuk, Magdalena . 31\nCreating, storing, and sharing your own web archives with open source Webrecorder tools\nMulliken, Jasmine Tiffany; Kreymer, Ilya . 33\nDH4MA - (Digital Humanities for Marginal Areas). Tangible and Intangible heritage digitalization to promote marginal areas and rural development\nPascucci, Antonio; Carlino, Carola; Monti, Johanna; Manna, Raffaele . 35\nDigital Humanities Applications of spaCy’s Span Categorizer\nBoyd, Adriane; Kádár, Ákos; Janco, Andrew; Lassner, David; Budak, Nick; Tasovac, Toma; Ermolaev, Natalia; Karajgikar,\nJajwalya . 36\nDigital Pathways Through Newspaper Advertisements: Workflows from Printed Page to Digital Analysis with the Avisblatt-R-Package\nDickmann, Lars; Reimann, Anna; Serif, Ina  38\nDrafting Standards for Stylometry\nJuola, Patrick; Byszuk, Joanna . 40\nFrameworks for User-Focused Digital Humanities Projects: Half-day workshop proposal\nMapp, Rennie; Wandl-Vogt, Eveline; Theron, Roberto  42\nFrom Sketching to Coding: Visualization as a Thinking Process\nHinrichs, Uta; Windhager, Florian; El-Assady, Mennatallah; Alexander, Eric; Bradley, Adam; Bludau, Mark-Jan  43\nHow can you trust your code?\nDamerow, Julia; Vogl, Malte; Koeser, Rebecca Sutton; Casties, Robert . 45\nLabs for Labs: a participatory workshop on digital lab practices in the humanities and social sciences\nKelly, Aodhán; Ciula, Arianna; Ferraro, Ginestra; Frissen, Thom; Papadopoulos, Costas; Rasterhoff, Claartje; Mellen, Pamela;\nNoël, Geoffroy . 45\nLEAF: Developing Streamlined Digital Scholarly Workflows with the Linked Editing Academic Framework\nJakacki, Diane Katherine; Brown, Susan; Cummings, James; Ilovan, Mihaela; Milio, Rachel  48\nMultilingual taxonomy initiative - TaDiRAH as community of practice\nBorek, Luise; Hastik, Canan; Dombrowski, Quinn; Broeder, Daan; Rockenberger, Annika; Nagasaki, Kiyonori; Mochizuki, Ryo;\nKatakura, Shumpei; Cupar, Drahomira; Ohmukai, Ikki  50\nOCR4all - Open-Source OCR and HTR Across the Centuries\nLanghanki, Florian; Wehner, Maximilian; Roeder, Torsten; Reul, Christian . 53\nPut Them In to Get Them Out: the ParlaMint Corpora for Digital Humanities and Social Sciences Research\nFišer, Darja; Kryvenko, Anna; Osenova, Petya; Pahor de Maiti, Kristina . 56\nSemantic Web and Linked Open Data in Historical Sciences\nKröger, Bärbel; Störiko, Johanna Sophia; Wettlaufer, Jörg . 57\nSIG-DLS Seven Years on\nRebora, Simone; Byszuk, Joanna; Frontini, Francesca; Herrmann, J. Berenike; Mpouli, Suzanne; Ruiz Fabo, Pablo  59\nSPARQL for (Digital) Humanists – Querying Wikidata and the MiMoTextBase\nRöttgermann, Julia; Duan, Tinghui; Hinzmann, Maria; Klee, Anne; Konstanciak, Johanna; Schö ...

# %% [markdown]
# each of the interview texts was loaded in a variable, called "text_nmb". To make things easier, we are going to put all these into a [dictionary](https://www.w3schools.com/python/python_dictionaries.asp), which will contain our texts.

# %%
corpus = {'2015': text_1,
          '2016': text_2,
          '2017': text_3,
          '2018': text_4,
          '2019': text_5,
          '2020': text_6,
          '2022': text_7,
          '2023': text_8}

# %% [markdown]
# We can check the size of our dictionary by calling the [len() function](https://www.w3schools.com/python/ref_func_len.asp):

# %%
len(corpus)
# Out:
# 8

# %% [markdown]
# we can then access each text by its index in the dictionary. Try it out: Try to access the '2016', or the '2018' one by changing the index value in the cell below:

# %%
corpus['2015']
# Out:
# 'Deux Projets D\'Édition Numérique Dans Le Cadre Du Projet SyMoGIH: Le Journal De Léonard Michon Et Les Actes Des Synodes Des Églises Réformées De Bourgogne\nVisualizing Mouvance: Towards an Alignment of Medieval Vernacular Text Traditions\nMapping Languages Performance by Performance\nA Study of Knowledge Integration in Digital Humanities Based on Bibliographic Analysis\nVerbal Identity of a Fictional Character: a Quantitative Study with a Machine Learning Experiment\nCombining Corpora and Statistics using Geographical Technologies: New Evidence on Nineteenth Century Infant Mortality Decline in England and Wales\nDigging into ECCO: Identifying Commonplaces and other Forms of Text Reuse at Scale\nRead, Play, Build: Teaching Sherlock Holmes through Digital Humanities\nChange, Transition and Governance: Lessons from a Long-Term, Large Scale DH Collaboration\nModelling Music Reception: An Ontology For Representing Interpretations of Richard Wagner\'s Leitmotifs\nAuthorship Attribution of Mediaeval German Text: Style and Contents in Apollonius von Tyrland \nWhat Do Boy Bands Tell Us About Disasters? The Social Media Response to the Nepal Earthquake \nMéthodes computationnelles et analyse d\'une langue de chancellerie : le logiciel d\'analyse textuelle Machiato et la correspondance diplomatique et administrative de Machiavel\nDigital Literary Stylistics Workshop\nFree FannyPacks: A Model for the Easy Digital Publication of Archival Periodical Material\nWhere Close and Distant Readings Meet: Text Clustering Methods in Literary Analysis of Weblog Genres\nBuilding Large Persons’ Networks to Explore Digital Corpora \nFrom Ashes to Ashé: Digital Disaster Archives as Memorials\nMicroanalyzing Parts of Texts\nMaking George Washington\'s Financial Documents Accessible: Transcription, Data, and the Drupal Solution \nDeveloping Local Digital Humanities Communities: The Atlanta Studies Network\nTowards an XML Corpora Exposition as LOD with the Lightweight Xquery-Based Framework SynopsX\nTool-based Identification of Melodic Patterns in MusicXML Documents\nMusic Information Retrieval Algorithms for Oral History Collections\nBiblissima - Following Medieval Manuscripts and Incunabula through their Existence via a Semantic Web Application\nA new approach to libraries in the Digital Humanities: the case of “Fonte-Gaia”\nRebuilding Digital Harlem for Sustainability and Change\nRAPSCAPE – un’esplorazione dell’universo linguistico del rap attraverso il text-mining e la data-visualization\nRegional Digital Humanities Consortia: An Emerging Formalization of Informal Network Ties?\nEtymology Meets Linked Data. A Case Study In Turkic \nCrosslingual Textual Emigration Analysis \nWhen Traditional Ontologies are not Enough: Modelling and Visualizing Dynamic Ontologies in Semantic-Based Access to Texts \nDiachronic Semantic Lexicon of Dutch (Diachroon semantisch lexicon van de Nederlandse Taal; DiaMaNT)\nStraight Talk! Automatic Recognition of Direct Speech in Nineteenth-Century French Novels \nDie digitale Modellierung experimenteller Druckgrafiken des 15. Jahrhunderts. Anforderungen und Chancen computerbasierter Dokumentationsverfahren\nComputation-Aided Analysis on Film Credits\nChoosing Words for Stylometric Authorship Attribution Evaluating Most Distinguishing Words (MDWs) vs. Most Frequent Words (MFWs)\nMaking Sense of Illustrated Handwritten Archives\nMapping Imagined and Experienced Places: An Exploration of the Geography of Willa Cather’s Writing\nDefining the Core Entities of an Environment for Textual Processing in Literary Computing \nSpotiBot-Turing testing Spotify\nOVAL: A Virtual Ecosystem for Immersive Scholarship and Teaching\nPerformance, the Document, and the Digital: the Case of Lynn Hershman Leeson’s ‘Robertas’\nArduino Circuits and Javanese Puppets: ‘Re-materializing’ Digital Archives through Tangible Interfaces\nHow IBM Watson Can Help Us Understand Character in Shakespeare: A Cognitive Computing Approach to the Plays. \nContextualizing ...

# %% [markdown]
# Congratulations! We now have loaded the data we want to analyse into Python. Now, we can start working on it.

# %% [markdown]
# ## Data Cleaning
#
# To turn our text into data that can be processed by an NLP algorithm, we need to remove punctuation and _stop words_, that is to say words we are not interested in. To do this, we can use regular expressions, string replacement, and the stopword functions provided by _nltk_. We will encapsulate all these operations in a function so that we can apply them to any text we want.

# %%
import re
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
def clean_and_tokenize(text):

  #removing line breaks
  text = text.replace('\n', ' ')

  #removing punctuation using a regular expression
  text = re.sub("[^-9A-Za-z ]", "" , text)
  text = text.lower()

  #tokenizing
  tokens = nltk.tokenize.word_tokenize(text)
  tokens

  # optional: we lemmatize the tokens
  # lemmatizer = WordNetLemmatizer()
  # tokens = [lemmatizer.lemmatize(i) for i in tokens]

  #removing stop words
  stopwords = nltk.corpus.stopwords.words('english')
  new_stopwords = ["the", "la", "to", "de","las", "le"]
  stopwords.extend(new_stopwords)

  clean_tokens = [i for i in tokens if i not in stopwords]

  return clean_tokens

# %%
text_to_tokenize = corpus['2017']
clean_and_tokenize(text_to_tokenize)
# Out:
# ['using',
#  'archival',
#  'texts',
#  'create',
#  'network',
#  'graphs',
#  'musicians',
#  'early',
#  'modern',
#  'venice',
#  'via',
#  'video-dance',
#  'computer-assisted',
#  'composition',
#  'mobile',
#  'technology',
#  'getting',
#  'medieval',
#  'open',
#  'access',
#  'networked',
#  'pedagogy',
#  'tracing',
#  'colors',
#  'clothing',
#  'paintings',
#  'image',
#  'analysis',
#  'google',
#  'cultural',
#  'institute',
#  'affect',
#  'collections',
#  'museums',
#  'case',
#  'turkey',
#  'digital',
#  'hansard',
#  'politics',
#  'uncivil',
#  'reconstructing',
#  'readerly',
#  'attention',
#  'citational',
#  'practices',
#  'canon',
#  '9-',
#  'coffee',
#  'zone',
#  'del',
#  'cafetal',
#  'al',
#  'futuro',
#  'coffee',
#  'fields',
#  'future',
#  'digital',
#  'humanities',
#  'critical',
#  'university',
#  'studies',
#  'machine',
#  'vision',
#  'algorithms',
#  'cadaster',
#  'plans',
#  'usability',
#  'testing',
#  'text',
#  'analysis',
#  'user-response',
#  'criticism',
#  'close',
#  'read',
#  'topic',
#  'model',
#  'twic',
#  'reads',
#  'emily',
#  'dickinsons',
#  'fascicles',
#  'distant',
#  'seeing',
#  'tv',
#  '9partition',
#  'margins',
#  'untold',
#  'testimonies',
#  'sikh',
#  'bahawalpur',
#  'marwari',
#  'communities',
#  'accessing',
#  'alternative',
#  'histories',
#  'futures',
#  'afro-latin',
#  'american',
#  'models',
#  'digital',
#  'humanities',
#  'data',
#  'visualization',
#  'archival',
#  'finding',
#  'aids',
#  'new',
#  'paradigm',
#  'access',
#  'aesthetic',
#  'appreciation',
#  'spanish',
#  'art',
#  'insights',
#  'eye-tracking',
#  'access',
#  'cultural',
#  'heritage',
#  'data',
#  'challenge',
#  'digital',
#  'humanities',
#  'natural',
#  'language',
#  'processing',
#  'long',
#  'tail',
#  'toponyms',
#  'entry',
#  'points',
#  'digital',
#  'edition',
#  'mapping',
#  'torch',
#  '99-9',
#  'memorekall',
#  'video',
#  'capsules',
#  'combination',
#  'intra',
#  'inter-documentary',
#  'approaches',
#  'address',
#  'documentation',
#  'performing',
#  'arts',
#  'critical',
#  'digital',
#  'humanities',
#  'machine-learning',
#  'archeologies',
#  'reading',
#  'modeling',
#  'recreating',
#  'annotation',
#  'practices',
#  'gabriel',
#  'harvey',
#  'john',
#  'dee',
#  'jacques',
#  'derrida',
#  'winthrop',
#  'family',
#  'binary',
#  'truths',
#  'developing',
#  'linked',
#  'data',
#  'model',
#  'historiographical',
#  'arguments',
#  'perseids',
#  'plokamos',
#  'weaving',
#  'pedagogy',
#  'data',
#  'models',
#  'tools',
#  'social',
#  'network',
#  'annotation',
#  'using',
#  'methods',
#  'computational',
#  'linguistics',
#  'resolving',
#  'homeric',
#  'question',
#  'towards',
#  'new',
#  'approach',
#  'study',
#  'ancient',
#  'greek',
#  'music',
#  'virtual',
#  'reconstruction',
#  'aulos',
#  'early',
#  'type',
#  'sicily',
#  'pushkin',
#  'digital',
#  'project',
#  'mapping',
#  'borges',
#  'argentine',
#  'publishing',
#  'industry',
#  '9-9',
#  'rewards',
#  'books',
#  'boundedness',
#  'reading',
#  'participatory',
#  'culture',
#  'object',
#  'classification',
#  'images',
#  'neoclassical',
#  'artifacts',
#  'using',
#  'deep',
#  'learning',
#  'embedding',
#  'digital',
#  'humanities',
#  'classics',
#  'master',
#  'programme',
#  'scaling',
#  'arts',
#  'humanities',
#  'dariah',
#  'approach',
#  'data',
#  'services',
#  'construire',
#  'sa',
#  'bibliothque',
#  'numrique',
#  'avec',
#  'loutil',
#  'libre',
#  'omeka',
#  'pour',
#  'valoriser',
#  'ses',
#  'documents',
#  'numriss',
#  'understanding',
#  'botnet-driven',
#  'blog',
#  'spam',
#  'motivations',
#  'methods',
#  'big-data',
#  'oriented',
#  'text',
#  'analysis',
#  'humanities',
#  'pedagogical',
#  'use',
#  'hathitrustbookworm',
#  'tool',
#  'database',
#  'online',
#  'book',
#  'response',
#  'nature',
#  'literary',
#  'thriller',
#  'facilitating',
#  'fine-grained',
#  'open',
#  'annotations',
#  'scholarly',
#  'sources',
#  'connect',
#  'intertextuality',
#  'circulation',
#  'networks',
#  'digital',
#  'resources',
#  'womens',
#  'writing',
#  'libraries',
#  'digital',
#  'research',
#  'sharing',
#  'incubator',
#  'built',
#  'app',
#  'revitalize',
#  'language',
#  'makers',
#  'mail',
#  'providing',
#  'makers',
#  'technologies',
#  'hack',
#  'yack',
#  'stack',
#  'access',
#  'culture',
#  'dh',
#  'infrastructure',
#  'dh',
#  'uncentered',
#  'fostering',
#  'partnerships',
#  'within',
#  'digital',
#  'humanities',
#  'network',
#  'university-community',
#  'digitization',
#  'partnerships',
#  'accessing',
#  'trans',
#  'collections',
#  'lgbt',
#  'community',
#  'archives',
#  'cultural',
#  're-formations',
#  'structuring',
#  'linked',
#  'data',
#  'ontology',
#  'intersectional',
#  'identities',
#  'advancing',
#  'linked',
#  'open',
#  'data',
#  'humanities',
#  'scaffolded',
#  'hermenutica',
#  'literary',
#  'scholars',
#  'novice',
#  'technical',
#  'skills',
#  'puns',
#  'intertextuality',
#  'digital',
#  'approach',
#  'greek',
#  'wordplay',
#  'latin',
#  'literature',
#  'humanities',
#  'data',
#  'centre',
#  'hdc',
#  'developing',
#  'services',
#  'heterogenous',
#  'humanities',
#  'research',
#  'data',
#  'course',
#  'emotion',
#  'three',
#  'centuries',
#  'german',
#  'texta',
#  'methodological',
#  'framework',
#  'optical',
#  'character',
#  'recognition',
#  'neural',
#  'network',
#  'model',
#  'coptic',
#  'layout',
#  'analysis',
#  'newspaper',
#  'archives',
#  'mapping',
#  'linked',
#  'data',
#  'subject',
#  'headings',
#  'library',
#  'catalog',
#  'preparation',
#  'topic',
#  'model',
#  'athar',
#  'numrisation',
#  'indexation',
#  'et',
#  'mise',
#  'en',
#  'ligne',
#  'enrichie',
#  'des',
#  'bulletins',
#  'du',
#  'comit',
#  'conservation',
#  'des',
#  'monuments',
#  'lart',
#  'arabe',
#  '-9',
#  'database',
#  'belarusian',
#  'periodicals',
#  'ten-year',
#  'summary',
#  'soa-based',
#  'micro-services',
#  'infrastructure',
#  'linguistic',
#  'services',
#  'neutralising',
#  'authorial',
#  'signal',
#  'delta',
#  'penalization',
#  'stylometric',
#  'clustering',
#  'genre',
#  'spanish',
#  'novels',
#  'rception',
#  'ldition',
#  'critique',
#  'numrique',
#  'accs',
#  'multiples',
#  'pour',
#  'publics',
#  'divers',
#  'mechanizing',
#  'humanities',
#  'kings',
#  'digital',
#  'lab',
#  'critical',
#  'experiment',
#  'new',
#  'improved',
#  'method',
#  'text-mining',
#  'chinese',
#  'closer',
#  'language',
#  'segmentation',
#  'detecting',
#  'shifting',
#  'meaning',
#  'patriotism',
#  'treating',
#  'genre',
#  'database',
#  'chinese',
#  'local',
#  'gazetteers',
#  'lg',
#  'tools',
#  'research',
#  'based',
#  'new',
#  'digital',
#  'methodology',
#  'new',
#  'literacy',
#  'practice',
#  'young',
#  'taiwanese',
#  'writers',
#  'illustrators',
#  'social',
#  'innovators',
#  'makers',
#  'networks',
#  'great',
#  'awakenings',
#  'classification',
#  'revival',
#  'sermons',
#  'word',
#  'usage',
#  'statistics',
#  'remembrance',
#  'contemporary',
#  'events',
#  'setting',
#  'sunflower',
#  'movement',
#  'archive',
#  'tempi',
#  'verbali',
#  'e',
#  'strutture',
#  'narrative',
#  'lanalisi',
#  'computazionale',
#  'dei',
#  'morfemi',
#  'temporali',
#  'nei',
#  'testi',
#  'narrativi',
#  'italiani',
#  'tra',
#  'realismo',
#  'e',
#  'modernismo',
#  'une',
#  'preuve',
#  'concept',
#  'pour',
#  'smantisation',
#  'et',
#  'visualisation',
#  'oriente',
#  'utilisateur',
#  'donnes',
#  'archivistiques',
#  'challenges',
#  'new',
#  'infrastructures',
#  'paradigms',
#  'dh',
#  'curricular',
#  'program',
#  'development',
#  'digital',
#  'religion',
#  'digital',
#  'theology',
#  'localisation',
#  'du',
#  'jaune',
#  'dans',
#  'des',
#  'dessins',
#  'dieux',
#  'raliss',
#  'par',
#  'des',
#  'enfants',
#  'digital',
#  'humanities',
#  'clinics',
#  'leading',
#  'dutch',
#  'librarians',
#  'dh',
#  'quill',
#  'reconstructing',
#  'secretarys',
#  'desk',
#  'records',
#  'convention',
#  'getting',
#  'metaphor',
#  'personal',
#  'matrix',
#  'generationally',
#  'mediated',
#  'realities',
#  'digital',
#  'culture',
#  'choice',
#  'tracing',
#  'swerves',
#  'influence',
#  'text',
#  'reuse',
#  'reception',
#  'lucretius',
#  'th-century',
#  'england',
#  'news',
#  'new',
#  'ads',
#  'extras',
#  'viral',
#  'texts',
#  'nineteenth-century',
#  'newspaper',
#  'page',
#  'queer',
#  'infrastructures',
#  'digital',
#  'intimacies',
#  'spaces',
#  'affordances',
#  'collaboration',
#  'active',
#  'archives',
#  'new',
#  'modes',
#  'interaction',
#  'online',
#  'archives',
#  'high-resolution',
#  'musicology',
#  'capturing',
#  'encoding',
#  'source',
#  'detail',
#  'medieval',
#  'music',
#  'dhconnections',
#  'examining',
#  'growth',
#  'digital',
#  'humanities',
#  'summer',
#  'institute',
#  'community',
#  'digital',
#  'musicology',
#  'research',
#  'teaching',
#  'beyond',
#  'historic',
#  'facade',
#  'skyscrapers',
#  'scapegoats',
#  'digital',
#  'reclamation',
#  'torontos',
#  'queer',
#  'streetscapes',
#  'digital',
#  'humanities',
#  'scratch',
#  'pedagogy-driven',
#  'investigation',
#  'in-copyright',
#  'corpus',
#  'world',
#  'difference',
#  'myths',
#  'misconceptions',
#  'tei',
#  'bodleian',
#  'tei',
#  'catalogue',
#  'consolidation',
#  'project',
#  'common',
#  'conceptual',
#  'model',
#  'study',
#  'poetry',
#  'digital',
#  'humanities',
#  'vers',
#  'les',
#  'donnes',
#  'lies',
#  'consquences',
#  'thoriques',
#  'et',
#  'pratiques',
#  'pour',
#  'les',
#  'sciences',
#  'humaines',
#  'extended',
#  'language',
#  'religious',
#  'reform',
#  'marking',
#  'register',
#  'early',
#  'modern',
#  'sermons',
#  'name',
#  'lizzie',
#  'bennet',
#  'reading',
#  'participation',
#  'jane',
#  'austen',
#  'across',
#  'media',
#  'platforms',
#  'lets',
#  'develop',
#  'infrastructure',
#  'historical',
#  'research',
#  'tools',
#  'serendipitous',
#  'moments',
#  'building',
#  'geo-located',
#  'mobile',
#  'application',
#  'letters',
#  '9',
#  'bernard',
#  'clairvaux',
#  'nicholas',
#  'montiramey',
#  'tracing',
#  'secretarial',
#  'trail',
#  'stylometry',
#  'numbers',
#  'notes',
#  'digital',
#  'prototyping',
#  'close',
#  'reading',
#  'ada',
#  'lovelaces',
#  'note',
#  'towards',
#  'linked',
#  'data',
#  'access',
#  'folktales',
#  'classified',
#  'thompsons',
#  'motifs',
#  'aarne-thompson-uthers',
#  'types',
#  'towards',
#  'integrated',
#  'set',
#  'annotations',
#  'folktales',
#  'modeling',
#  'place',
#  'ulysses',
#  'ontologies',
#  'pre-texts',
#  'automatically',
#  'analyzing',
#  'recordings',
#  'musical',
#  'performances',
#  'leveraging',
#  'expert',
#  'domain',
#  'knowledge',
#  'learn',
#  'representation',
#  'symbolic',
#  'music',
#  'creating',
#  'policy',
#  'framework',
#  'analytic',
#  'access',
#  'in-copyright',
#  'works',
#  'non-consumptive',
#  'research',
#  'high',
#  'performance',
#  'computing',
#  'photogrammetry',
#  'ocr',
#  'made',
#  'easy',
#  'research',
#  'computings',
#  'demand',
#  'humanists',
#  'vice',
#  'versa',
#  'capacity',
#  'building',
#  'framework',
#  'institutional',
#  'digital',
#  'humanities',
#  'support',
#  'neoclassica',
#  'open',
#  'framework',
#  'research',
#  'neoclassicism',
#  'lextraction',
#  'automatique',
#  'des',
#  'motifs',
#  'dramaturgiques',
#  'dans',
#  'les',
#  'squences',
#  'deux',
#  'scnes',
#  'authorship',
#  'dream',
#  'red',
#  'chamber',
#  'topic',
#  'modeling',
#  'approach',
#  'come',
#  'together',
#  'right',
#  'discovery',
#  'interoperability',
#  'born-digital',
#  'music',
#  'scholarship',
#  'access',
#  'determines',
#  'whole',
#  'structuration',
#  'european',
#  'infrastructure',
#  'example',
#  'dariah',
#  'corpora',
#  'complex',
#  'networks',
#  'cultural',
#  'critique',
#  'investigating',
#  'race',
#  'gender',
#  'bias',
#  'graphic',
#  'narratives',
#  'sance',
#  'dinitiation',
#  'vido',
#  'adapte',
#  'recherche',
#  'shs',
#  'introducing',
#  'open',
#  'online',
#  'newspaper',
#  'initiative',
#  'alternate',
#  'histories',
#  'digital',
#  'humanities',
#  'short',
#  'samples',
#  'authorship',
#  'attribution',
#  'new',
#  'approach',
#  'go',
#  'queer',
#  'producing',
#  'queer',
#  'place',
#  'locative',
#  'media',
#  'augmented',
#  'dance',
#  'scholarship',
#  'computer-assisted',
#  'analysis',
#  'javanese',
#  'dance',
#  'making',
#  'manuscripts',
#  'searchable',
#  'dex',
#  'database',
#  'dramatic',
#  'extracts',
#  'digital',
#  'publication',
#  'boutique',
#  'projects',
#  'une',
#  'approche',
#  'conception',
#  'collaborative',
#  'et',
#  'dexploitation',
#  'des',
#  'modles',
#  'ontologiques',
#  'des',
#  'donnes',
#  'facilement',
#  'extensibles',
#  'et',
#  'compatibles',
#  'avec',
#  'web',
#  'des',
#  'donnes',
#  'ouvertes',
#  'lod',
#  'pour',
#  'les',
#  'humanits',
#  'numriques',
#  'dh',
#  'editorial',
#  'chain',
#  'research',
#  'platform',
#  'structuring',
#  'enriching',
#  'publishing',
#  'large',
#  'collections',
#  'digitized',
#  'scientific',
#  'publications',
#  'toward',
#  'typology',
#  'digital',
#  'thematic',
#  'research',
#  'collections',
#  'characters',
#  '9th',
#  'century',
#  'novels',
#  'display',
#  'distinctive',
#  'voices',
#  'seen',
#  'stylometric',
#  'analysis',
#  'modelling',
#  'prosopography',
#  'roman',
#  'republic',
#  'network',
#  'dynamics',
#  'plot',
#  'analysis',
#  'approaching',
#  'progressive',
#  'structuration',
#  'literary',
#  'texts',
#  'seven',
#  'words',
#  'virgin',
#  'identifying',
#  'change',
#  'discourse',
#  'context',
#  'concept',
#  'virginity',
#  'early',
#  'modern',
#  'english',
#  'design',
#  'historical',
#  'data',
#  'projects',
#  'les',
#  'registres',
#  'comdie',
#  'franaise',
#  'laboratoire',
#  'paris',
#  'xviii',
#  'read',
#  'wedding',
#  'comparative',
#  'discourse',
#  'analysis',
#  'fan',
#  'responses',
#  'game',
#  'thrones',
#  'quoi',
#  'est-il',
#  'question',
#  'dans',
#  'discours',
#  'en',
#  'art',
#  'contemporain',
#  'fouille',
#  'textes',
#  'applique',
#  'lart',
#  'contemporain',
#  'dans',
#  'les',
#  'centres',
#  'dartistes',
#  'enhanced',
#  'rti',
#  'arts',
#  'humanities',
#  'transcription',
#  'encoded',
#  'manuscripts',
#  ...]

# %% [markdown]
# ## Ngrams, Ngram Frequencies and Visualisation

# %% [markdown]
# We need a number of functions from the _nltk_ library, which will allow us to create ngrams from our tokens, and look at their distribution in our texts.

# %%
from nltk import ngrams, FreqDist, bigrams

# %%
all_text = " ".join(corpus.values())
clean_tokens = clean_and_tokenize(all_text)
clean_ngrams = ngrams(clean_tokens,2)

# %%
ngram_fd = FreqDist(clean_ngrams).most_common(20)
ngram_fd

# %% [markdown]
# We will use a visualisation library called _matplotlib_ to visualize the frequency of ngrams in our texts.

# %%
import matplotlib.pyplot as plt

# %%
# join the words with '_' in the middle
wrds = ['_'.join(x) for x, c in ngram_fd]

# get the counts
wdth = [c for x, c in ngram_fd]

plt.barh(wrds, wdth, color='blue')

# %% [markdown]
# We can package the code necessary to build a chart of the 20 most common ngrams for some text into a function, which is defined below. We can then run this function with any part of the corpus that we wish, and compare the results.

# %%
def show_top_20_ngrams(year, number_of_tokens):
  clean_tokens = clean_and_tokenize(corpus[year])
  clean_ngrams = ngrams(clean_tokens,number_of_tokens)
  ngram_fd = FreqDist(clean_ngrams).most_common(20)
  wrds = ['_'.join(x) for x, c in ngram_fd]
  wdth = [c for x, c in ngram_fd]
  plt.barh(wrds, wdth, color='blue')
  plt.title(year)

# %%
year = '2020'
ngram_size = 3
show_top_20_ngrams(year,ngram_size)

# %%
year = '2017'
ngram_size = 3
show_top_20_ngrams(year,ngram_size)

# %% [markdown]
# ##Word Embeddings

# %% [markdown]
# To perform word embeddings, we're going to use another library called _gensim_.

# %%
import gensim
from gensim.models import Word2Vec
from nltk import sent_tokenize, word_tokenize

# %%
#stop words
stopwords = nltk.corpus.stopwords.words('english')
new_stopwords = ["the", "la", "to", "de","las", "an"]
stopwords.extend(new_stopwords)

# %%
# we will work on the whole text at once, and extract the sentences from it.
all_text = " ".join(corpus.values())
data = []

# iterate through each sentence in the file
for i in sent_tokenize(all_text):
    temp = []

    # tokenize the sentence into words. We discard stop words and punctuation.
    for j in word_tokenize(i):
      j = j.lower()
      if (j not in stopwords) and j.isalpha():
        temp.append(j)

    data.append(temp)
data[0]

# %%
# Create CBOW model
model = gensim.models.Word2Vec(data, min_count = 1, window = 10, batch_words = 10)

# %%
word_to_check = 'dh'
number_of_similar_words = 5
model.wv.most_similar(word_to_check, topn=number_of_similar_words)

# %% [markdown]
# ## Name Entity Recognition
# NER is a process through which a chunk of text is parsed through to find entities that can be put under categories such as people, organizations, locations, etc.
#
# We will use Spacy, an NLP library, to perform basic NER on our text.

# %% [markdown]
# Due to a quirk of the model we wish to use, we need to ensure that we are working with the correct encoding, i.e UTF-8. The lines below ensure that it is the case.

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
import spacy

# %% [markdown]
# We need a pre-trained model (in english), which will perform the NER for us. We could also train our own model, but in this case we borrow this model from Spacy.

# %%
# !python -m spacy download en_core_web_sm

# %%
nlp = spacy.load("en_core_web_sm")

# %%
from spacy import displacy

text_for_ner = corpus['2018']
doc = nlp(text_for_ner)
displacy.render(doc, style='ent', jupyter=True, options={'distance': 90})
